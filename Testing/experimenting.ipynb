# %%
# %cd D:\Langchain\Testing
# Out:
# D:\Langchain\Testing

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.190  Python-3.12.2 torch-2.8.0+cpu CPU (AMD Ryzen 5 3500U with Radeon Vega Mobile Gfx)
# Setup complete  (8 CPUs, 5.9 GB RAM, 60.1/464.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# !yolo task=detect mode=predict model = "D:\\Langchain\\Testing\\best.pt" show=True conf=0.5 source="D:\\Langchain\\Testing\\testvideo1.mp4"
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
# Ultralytics 8.3.190  Python-3.12.2 torch-2.8.0+cpu CPU (AMD Ryzen 5 3500U with Radeon Vega Mobile Gfx)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/529) D:\Langchain\Testing\testvideo1.mp4: 352x640 (no detections), 272.7ms
# video 1/1 (frame 2/529) D:\Langchain\Testing\testvideo1.mp4: 352x640 (no detections), 290.0ms
# video 1/1 (frame 3/529) D:\Langchain\Testing\testvideo1.mp4: 352x640 (no detections), 238.7ms
# video 1/1 (frame 4/529) D:\Langchain\Testing\testvideo1.mp4: 352x640 (no detections), 192.0ms
# video 1/1 (frame 5/529) D:\Langchain\Testing\testvideo1.mp4: 352x640 (no detections), 197.1ms
# video 1/1 (frame 6/529) D:\Langchain\Testing\testvideo1.mp4: 352x640 (no detections), 203.4ms
# ...

# %%
# !yolo task=detect mode=predict model = "D:\\Langchain\\Testing\\best.pt" show=True conf=0.5 source="D:\\Langchain\\Testing\\testvideo2.mp4"
# Out:
# Ultralytics 8.3.190  Python-3.12.2 torch-2.8.0+cpu CPU (AMD Ryzen 5 3500U with Radeon Vega Mobile Gfx)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/405) D:\Langchain\Testing\testvideo2.mp4: 352x640 (no detections), 309.9ms
# video 1/1 (frame 2/405) D:\Langchain\Testing\testvideo2.mp4: 352x640 (no detections), 286.0ms
# video 1/1 (frame 3/405) D:\Langchain\Testing\testvideo2.mp4: 352x640 (no detections), 221.5ms
# video 1/1 (frame 4/405) D:\Langchain\Testing\testvideo2.mp4: 352x640 (no detections), 203.9ms
# video 1/1 (frame 5/405) D:\Langchain\Testing\testvideo2.mp4: 352x640 (no detections), 207.2ms
# video 1/1 (frame 6/405) D:\Langchain\Testing\testvideo2.mp4: 352x640 (no detections), 205.7ms
# video 1/1 (frame 7/405) D:\Langchain\Testing\testvideo2.mp4: 352x640 (no detections), 185.8ms
# video 1/1 (frame 8/405) D:\Langchain\Testing\testvideo2.mp4: 352x640 (no detections), 188.5ms
# ...

# %%
# !yolo task=detect mode=predict model = "D:\\Langchain\\Testing\\best.pt" show=True conf=0.5 source="D:\\Langchain\\Testing\\testvideo3.mp4"
# Out:
# Ultralytics 8.3.190  Python-3.12.2 torch-2.8.0+cpu CPU (AMD Ryzen 5 3500U with Radeon Vega Mobile Gfx)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/896) D:\Langchain\Testing\testvideo3.mp4: 384x640 (no detections), 272.3ms
# video 1/1 (frame 2/896) D:\Langchain\Testing\testvideo3.mp4: 384x640 (no detections), 314.3ms
# video 1/1 (frame 3/896) D:\Langchain\Testing\testvideo3.mp4: 384x640 (no detections), 260.0ms
# video 1/1 (frame 4/896) D:\Langchain\Testing\testvideo3.mp4: 384x640 (no detections), 218.6ms
# video 1/1 (frame 5/896) D:\Langchain\Testing\testvideo3.mp4: 384x640 (no detections), 231.6ms
# video 1/1 (frame 6/896) D:\Langchain\Testing\testvideo3.mp4: 384x640 (no detections), 207.3ms
# video 1/1 (frame 7/896) D:\Langchain\Testing\testvideo3.mp4: 384x640 (no detections), 209.3ms
# video 1/1 (frame 8/896) D:\Langchain\Testing\testvideo3.mp4: 384x640 (no detections), 209.6ms
# ...
